# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Исследовательский-анализ-и-предобработка-данных" data-toc-modified-id="Исследовательский-анализ-и-предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследовательский анализ и предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Данные-об-электродах" data-toc-modified-id="Данные-об-электродах-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Данные об электродах</a></span></li><li><span><a href="#Данные-о-подаче-сыпучих-материалов-(объём)" data-toc-modified-id="Данные-о-подаче-сыпучих-материалов-(объём)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Данные о подаче сыпучих материалов (объём)</a></span></li><li><span><a href="#Данные-о-подаче-сыпучих-материалов-(время)" data-toc-modified-id="Данные-о-подаче-сыпучих-материалов-(время)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Данные о подаче сыпучих материалов (время)</a></span></li><li><span><a href="#Данные-о-проволочных-материалах-(объём)" data-toc-modified-id="Данные-о-проволочных-материалах-(объём)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Данные о проволочных материалах (объём)</a></span></li><li><span><a href="#Данные-о-проволочных-материалах-(время)" data-toc-modified-id="Данные-о-проволочных-материалах-(время)-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Данные о проволочных материалах (время)</a></span></li><li><span><a href="#Данные-о-продувке-сплава-газом" data-toc-modified-id="Данные-о-продувке-сплава-газом-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Данные о продувке сплава газом</a></span></li><li><span><a href="#Результаты-измерения-температуры" data-toc-modified-id="Результаты-измерения-температуры-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Результаты измерения температуры</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Объединение-датасетов" data-toc-modified-id="Объединение-датасетов-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Объединение датасетов</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-и-предобработка-данных-объединённого-датафрейма" data-toc-modified-id="Исследовательский-анализ-и-предобработка-данных-объединённого-датафрейма-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ и предобработка данных объединённого датафрейма</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Обучение-моделей-машинного-обучения" data-toc-modified-id="Обучение-моделей-машинного-обучения-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Обучение моделей машинного обучения</a></span></li><li><span><a href="#Выбор-лучшей-модели" data-toc-modified-id="Выбор-лучшей-модели-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Выбор лучшей модели</a></span><ul class="toc-item"><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Сравнение моделей</a></span></li><li><span><a href="#Метрики-лучшей-модели" data-toc-modified-id="Метрики-лучшей-модели-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Метрики лучшей модели</a></span></li><li><span><a href="#Сравнение-с-константной-моделью" data-toc-modified-id="Сравнение-с-константной-моделью-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Сравнение с константной моделью</a></span></li><li><span><a href="#Важность-признаков-лучшей-модели" data-toc-modified-id="Важность-признаков-лучшей-модели-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Важность признаков лучшей модели</a></span></li></ul></li><li><span><a href="#Общий-вывод-и-рекомендации-заказчику" data-toc-modified-id="Общий-вывод-и-рекомендации-заказчику-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Общий вывод и рекомендации заказчику</a></span></li></ul></div>

# %% [markdown]
# # Прогнозирование температуры сплава

# %% [markdown]
# Чтобы оптимизировать производственные расходы, металлургический комбинат «Стальная птица» решил уменьшить потребление электроэнергии на этапе обработки стали. Для этого комбинату нужно контролировать температуру сплава. Задача — построить модель, которая будет её предсказывать.
# Заказчик хочет использовать разработанную модель для имитации технологического процесса.
#
# **Описание этапа обработки**\
# Сталь обрабатывают в металлическом ковше вместимостью около 100 тонн. Чтобы ковш выдерживал высокие температуры, изнутри его облицовывают огнеупорным кирпичом. Расплавленную сталь заливают в ковш и подогревают до нужной температуры графитовыми электродами. Они установлены в крышке ковша.\
# Из сплава выводится сера (этот процесс — десульфурация), добавлением примесей корректируется химический состав и отбираются пробы. Сталь легируют — изменяют её состав — подавая куски сплава из бункера для сыпучих материалов или проволоку через специальный трайб-аппарат (от англ. tribe — «масса»).\
# Перед тем как первый раз ввести легирующие добавки, измеряют температуру стали и производят её химический анализ. Потом температуру на несколько минут повышают, добавляют легирующие материалы и продувают сплав инертным газом. Затем его перемешивают и снова проводят измерения. Такой цикл повторяется до достижения целевого химического состава и оптимальной температуры плавки.\
# Тогда расплавленная сталь отправляется на доводку металла или поступает в машину непрерывной разливки. Оттуда готовый продукт выходит в виде заготовок-слябов (от англ. slab — «плита»)

# %% [markdown]
# **Цель проекта**\
# Построить модель, которая будет предсказывать температуру сплава, для оптимизации потребления электроэнергии на этапе обработки стали.

# %%
# !pip install phik -q

# %%
import pandas as pd

import numpy as np

import phik

import seaborn as sns

from matplotlib import pyplot as plt

from sklearn.pipeline import Pipeline

from sklearn.preprocessing import (
    StandardScaler, 
    MinMaxScaler
)

from sklearn.compose import ColumnTransformer

from sklearn.inspection import permutation_importance

from sklearn.model_selection import train_test_split, RandomizedSearchCV

from sklearn.metrics import mean_absolute_error, r2_score

from sklearn.dummy import DummyRegressor

from sklearn.tree import DecisionTreeRegressor

from catboost import CatBoostRegressor

from xgboost import XGBRegressor

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Загрузите данные и выполните их первичный осмотр.

# %%
#создадим функцию для вывода общей информации о датасете
def main_info(data):
    display(data.head())
    data.info()
    display(data.describe().T)
    return

# %% [markdown]
# Загрузим данные

# %%
data_arc_new = pd.read_csv('data_arc_new.csv')

# %%
data_bulk_new = pd.read_csv('datasets/data_bulk_new.csv')

# %%
data_bulk_time_new = pd.read_csv('datasets/data_bulk_time_new.csv')

# %%
data_gas_new = pd.read_csv('datasets/data_gas_new.csv')

# %%
data_temp_new = pd.read_csv('datasets/data_temp_new.csv')

# %%
data_wire_new = pd.read_csv('datasets/data_wire_new.csv')

# %%
data_wire_time_new = pd.read_csv('datasets/data_wire_time_new.csv')

# %% [markdown]
# ## Исследовательский анализ и предобработка данных

# %% [markdown]
# ### Данные об электродах

# %%
#выведем инфо о первом датасете
main_info(data_arc_new)
# Out:
#    key Начало нагрева дугой  Конец нагрева дугой  Активная мощность  \
# 0    1  2019-05-03 11:02:14  2019-05-03 11:06:02           0.305130
# 1    1  2019-05-03 11:07:28  2019-05-03 11:10:33           0.765658
# 2    1  2019-05-03 11:11:44  2019-05-03 11:14:36           0.580313
# 3    1  2019-05-03 11:18:14  2019-05-03 11:24:19           0.518496
# 4    1  2019-05-03 11:26:09  2019-05-03 11:28:37           0.867133
#
#    Реактивная мощность
# 0             0.211253
# 1             0.477438
# 2             0.430460
# 3             0.379979
# 4             0.643691
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   key                   14876 non-null  int64
#  1   Начало нагрева дугой  14876 non-null  object
#  2   Конец нагрева дугой   14876 non-null  object
#  3   Активная мощность     14876 non-null  float64
# ...

# %% [markdown]
# В датасете нет пропусков, столбцы с началом и концом нагрева дугой имеют неверный тип данных, названия столбцов также не выполнены по правилам.
# Также можно отметить наличие отрицательной реактивной мощности - удалим это значение

# %%
#переименуем столбцы
data_arc_new.columns = data_arc_new.columns.str.replace(' ', '_', regex=True)
data_arc_new.columns = data_arc_new.columns.str.lower()

# %%
#приведем типы данных к datetime
data_arc_new['начало_нагрева_дугой'] = pd.to_datetime(
    data_arc_new['начало_нагрева_дугой'], format='%Y-%m-%d %H:%M:%S'
)

# %%
#приведем типы данных к datetime
data_arc_new['конец_нагрева_дугой'] = pd.to_datetime(
    data_arc_new['конец_нагрева_дугой'], format='%Y-%m-%d %H:%M:%S'
)

# %%
num_col_names = data_arc_new.select_dtypes(include='number').columns.tolist()

# %%
#построение графиков для количественных признаков
for i, col_name in enumerate(num_col_names):
    fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
    data_arc_new[col_name].plot(kind='hist', bins=20, ax=axes[0])
    axes[0].set_title(f'Гистограмма распределения')
    axes[0].set_ylabel('Частота')
    data_arc_new[col_name].plot(kind='box', ax=axes[1], vert=False)
    axes[1].set_title(f'Диаграмма размаха')
    axes[1].set_xlabel(f'{col_name}')
    axes[1].set_yticks([])
    fig.tight_layout()  
    plt.show()

# %% [markdown]
# Можно отметить, что каждая партия представлена равномерна по количеству нагревов.
# Активная мощность имеет нормальное распределение со скошенностью вправо, присутствуют выбросы на диапазоне больших значений. На графике реактивной мощности мешает выброс - удалим его для анализа.

# %%
data_arc_alt = data_arc_new.copy(deep=True)

# %%
data_arc_alt[data_arc_alt['реактивная_мощность'] < 0]
# Out:
#        key начало_нагрева_дугой конец_нагрева_дугой  активная_мощность  \
# 9780  2116  2019-07-28 02:22:08 2019-07-28 02:23:57           0.705344
#
#       реактивная_мощность
# 9780          -715.479924

# %%
data_arc_alt = data_arc_alt.query('key !=2116')

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 6))
data_arc_alt['реактивная_мощность'].plot(kind='hist', bins=20, ax=axes[0])
axes[0].set_title(f'Гистограмма распределения')
axes[0].set_ylabel('Частота')
data_arc_alt['реактивная_мощность'].plot(kind='box', ax=axes[1], vert=False)
axes[1].set_title(f'Диаграмма размаха')
axes[1].set_xlabel('Реактивная_мощность')
axes[1].set_yticks([])
fig.tight_layout()  
plt.show()

# %% [markdown]
# Реактивная мощность также имеет нормальное распределение со скошенностью вправо. Присутствуют выбросы со значениями мощность примерно > 1

# %%
#сгенерируем новый признак 
data_arc_alt['время_нагрева'] = (
    data_arc_alt['конец_нагрева_дугой'] - data_arc_alt['начало_нагрева_дугой']
).dt.total_seconds()

# %%
data_arc_alt.head(10)
# Out:
#    key начало_нагрева_дугой конец_нагрева_дугой  активная_мощность  \
# 0    1  2019-05-03 11:02:14 2019-05-03 11:06:02           0.305130
# 1    1  2019-05-03 11:07:28 2019-05-03 11:10:33           0.765658
# 2    1  2019-05-03 11:11:44 2019-05-03 11:14:36           0.580313
# 3    1  2019-05-03 11:18:14 2019-05-03 11:24:19           0.518496
# 4    1  2019-05-03 11:26:09 2019-05-03 11:28:37           0.867133
# 5    2  2019-05-03 11:34:14 2019-05-03 11:36:31           0.381124
# 6    2  2019-05-03 11:38:50 2019-05-03 11:44:28           0.261665
# 7    2  2019-05-03 11:46:19 2019-05-03 11:48:25           0.710297
# 8    2  2019-05-03 11:49:48 2019-05-03 11:53:18           0.786322
# 9    3  2019-05-03 12:06:54 2019-05-03 12:11:34           1.101678
#
#    реактивная_мощность  время_нагрева
# 0             0.211253          228.0
# 1             0.477438          185.0
# 2             0.430460          172.0
# 3             0.379979          365.0
# ...

# %%
#агрегируем данные и добавим новый признак - число итераций нагрева
data_arc_pivot = data_arc_alt.pivot_table(
    index='key',
    values=['активная_мощность','реактивная_мощность','время_нагрева', 'начало_нагрева_дугой'],
    aggfunc={'активная_мощность':'sum',
             'реактивная_мощность':'sum',
             'время_нагрева':'sum',
             'начало_нагрева_дугой':'count'
            }
)

data_arc_pivot.rename(columns={'начало_нагрева_дугой':'число_итераций_нагрева'}, inplace=True)
data_arc_pivot.reset_index(inplace=True)

# %%
#сгенерируем новые признаки, для этого посчитаем полную мощность и работу по формулам
data_arc_pivot['полная_мощность'] = (
    data_arc_pivot['активная_мощность']**2 + data_arc_pivot['реактивная_мощность']**2
)**0.5

# %%
data_arc_pivot['работа'] = data_arc_pivot['полная_мощность']*data_arc_pivot['время_нагрева']

# %%
data_arc_pivot.head(10)
# Out:
#    key  активная_мощность  время_нагрева  число_итераций_нагрева  \
# 0    1           3.036730         1098.0                       5
# 1    2           2.139408          811.0                       4
# 2    3           4.063641          655.0                       5
# 3    4           2.706489          741.0                       4
# 4    5           2.252950          869.0                       4
# 5    6           2.725274          952.0                       4
# 6    7           2.626877          673.0                       4
# 7    8           2.678958          913.0                       4
# 8    9           3.520820          625.0                       5
# 9   10           3.118778          825.0                       6
#
#    реактивная_мощность  полная_мощность       работа
# 0             2.142821         3.716640  4080.870431
# 1             1.453357         2.586371  2097.546600
# 2             2.937457         5.014163  3284.276844
# ...

# %% [markdown]
# ### Данные о подаче сыпучих материалов (объём)

# %%
main_info(data_bulk_new)
# Out:
#    key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# 0    1     NaN     NaN     NaN    43.0     NaN     NaN     NaN     NaN
# 1    2     NaN     NaN     NaN    73.0     NaN     NaN     NaN     NaN
# 2    3     NaN     NaN     NaN    34.0     NaN     NaN     NaN     NaN
# 3    4     NaN     NaN     NaN    81.0     NaN     NaN     NaN     NaN
# 4    5     NaN     NaN     NaN    78.0     NaN     NaN     NaN     NaN
#
#    Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 0     NaN      NaN      NaN    206.0      NaN    150.0    154.0
# 1     NaN      NaN      NaN    206.0      NaN    149.0    154.0
# 2     NaN      NaN      NaN    205.0      NaN    152.0    153.0
# 3     NaN      NaN      NaN    207.0      NaN    153.0    154.0
# 4     NaN      NaN      NaN    203.0      NaN    151.0    152.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ...

# %% [markdown]
# В данных достаточно большое количество пропусков, названия столбцов не соответствуют правилам

# %%
#переименуем столбцы
data_bulk_new.columns = data_bulk_new.columns.str.replace(' ', '_', regex=True)
data_bulk_new.columns = data_bulk_new.columns.str.lower()

# %%
fig = plt.figure()

i=1
for col_name in data_bulk_new.columns.tolist():
    ax = fig.add_subplot(4, 4, i)
    data_bulk_new[col_name].plot(kind='hist', bins=20, figsize=(14, 14))
    ax.set_title(f'Гистограмма распределения')
    ax.set_ylabel('Частота')
    ax.set_xlabel(f'{col_name}')
    i+=1
fig.tight_layout()  
plt.show()

# %% [markdown]
# Гистограммы распределения объема сыпучих материалов практически не имеют нормального распределения, это можно обсуловить тем, что не все виды добавок добавляются в равной мере по партиям и во многих столбцах есть большое количество пропусков

# %%
#выведем долю пропусков в каждом столбце
data_bulk_new.isna().sum()/data_bulk_new.shape[0]
# Out:
# key        0.000000
# bulk_1     0.919463
# bulk_2     0.992969
# bulk_3     0.585171
# bulk_4     0.675935
# bulk_5     0.975391
# bulk_6     0.815916
# bulk_7     0.992010
# bulk_8     0.999680
# bulk_9     0.993928
# bulk_10    0.943752
# bulk_11    0.943432
# bulk_12    0.217002
# bulk_13    0.994247
# bulk_14    0.103228
# bulk_15    0.281560
# dtype: float64

# %% [markdown]
# Для отбора признаков принято решение удалить те, в которых более 80% пропусков. В остальных случаях заменим пропуски на нули - это будет означать, что данные материалы не добавлялись и будут значимы для анализа.

# %%
#удалим столбцы с 80% пропусков
data_bulk_new = data_bulk_new.dropna(thresh=int(len(data_bulk_new) * .2), axis=1)

# %%
#заменим пропуски на нули
data_bulk_new = data_bulk_new.fillna(0)

# %%
data_bulk_new.head(10)
# Out:
#    key  bulk_3  bulk_4  bulk_12  bulk_14  bulk_15
# 0    1     0.0    43.0    206.0    150.0    154.0
# 1    2     0.0    73.0    206.0    149.0    154.0
# 2    3     0.0    34.0    205.0    152.0    153.0
# 3    4     0.0    81.0    207.0    153.0    154.0
# 4    5     0.0    78.0    203.0    151.0    152.0
# 5    6     0.0   117.0    204.0    201.0    154.0
# 6    7     0.0   117.0    204.0    152.0    154.0
# 7    8     0.0    99.0    410.0    252.0    153.0
# 8    9     0.0   117.0    107.0     99.0    203.0
# 9   10     0.0     0.0    203.0    102.0    204.0

# %% [markdown]
# ###  Данные о подаче сыпучих материалов (время)

# %%
main_info(data_bulk_time_new)
# Out:
#    key Bulk 1 Bulk 2 Bulk 3               Bulk 4 Bulk 5 Bulk 6 Bulk 7 Bulk 8  \
# 0    1    NaN    NaN    NaN  2019-05-03 11:28:48    NaN    NaN    NaN    NaN
# 1    2    NaN    NaN    NaN  2019-05-03 11:36:50    NaN    NaN    NaN    NaN
# 2    3    NaN    NaN    NaN  2019-05-03 12:32:39    NaN    NaN    NaN    NaN
# 3    4    NaN    NaN    NaN  2019-05-03 12:43:22    NaN    NaN    NaN    NaN
# 4    5    NaN    NaN    NaN  2019-05-03 13:30:47    NaN    NaN    NaN    NaN
#
#   Bulk 9 Bulk 10 Bulk 11              Bulk 12 Bulk 13              Bulk 14  \
# 0    NaN     NaN     NaN  2019-05-03 11:24:31     NaN  2019-05-03 11:14:50
# 1    NaN     NaN     NaN  2019-05-03 11:53:30     NaN  2019-05-03 11:48:37
# 2    NaN     NaN     NaN  2019-05-03 12:27:13     NaN  2019-05-03 12:21:01
# 3    NaN     NaN     NaN  2019-05-03 12:58:00     NaN  2019-05-03 12:51:11
# 4    NaN     NaN     NaN  2019-05-03 13:30:47     NaN  2019-05-03 13:34:12
#
#                Bulk 15
# 0  2019-05-03 11:10:43
# ...

# %% [markdown]
# Видим большое количество пропусков, в соответствии с предыдущим датасетом. Типы данных не соответствуют ожидаемым datetime.

# %%
data_bulk_time_new.set_index('key', inplace=True)

# %%
#переименуем столбцы
data_bulk_time_new.columns = data_bulk_time_new.columns.str.replace(' ', '_', regex=True)+'_time'
data_bulk_time_new.columns = data_bulk_time_new.columns.str.lower()

# %%
#удалим признаки с более чем 80% пропусков
data_bulk_time_new = data_bulk_time_new.dropna(thresh=int(len(data_bulk_time_new) * .2), axis=1)

# %%
data_bulk_time_new.head(10)
# Out:
#     bulk_3_time          bulk_4_time         bulk_12_time  \
# key
# 1           NaN  2019-05-03 11:28:48  2019-05-03 11:24:31
# 2           NaN  2019-05-03 11:36:50  2019-05-03 11:53:30
# 3           NaN  2019-05-03 12:32:39  2019-05-03 12:27:13
# 4           NaN  2019-05-03 12:43:22  2019-05-03 12:58:00
# 5           NaN  2019-05-03 13:30:47  2019-05-03 13:30:47
# 6           NaN  2019-05-03 13:57:27  2019-05-03 13:48:52
# 7           NaN  2019-05-03 14:18:58  2019-05-03 14:41:26
# 8           NaN  2019-05-03 15:17:58  2019-05-03 15:17:58
# 9           NaN  2019-05-03 16:03:08  2019-05-03 16:03:08
# 10          NaN                  NaN  2019-05-03 16:38:11
#
#             bulk_14_time         bulk_15_time
# key
# 1    2019-05-03 11:14:50  2019-05-03 11:10:43
# 2    2019-05-03 11:48:37  2019-05-03 11:44:39
# 3    2019-05-03 12:21:01  2019-05-03 12:16:16
# 4    2019-05-03 12:51:11  2019-05-03 12:46:36
# 5    2019-05-03 13:34:12  2019-05-03 13:30:47
# ...

# %%
data_bulk_time_new = data_bulk_time_new.apply(lambda x: pd.to_datetime(x, format='%Y-%m-%d %H:%M:%S'))

# %%
#сгенерируем новый признак время подачи материала
data_bulk_time_new['время_подачи_материала'] = data_bulk_time_new.apply(
    lambda x: (x.max()-x.min()).total_seconds(), axis=1
)

# %%
data_bulk_time_new.head(10)
# Out:
#     bulk_3_time         bulk_4_time        bulk_12_time        bulk_14_time  \
# key
# 1           NaT 2019-05-03 11:28:48 2019-05-03 11:24:31 2019-05-03 11:14:50
# 2           NaT 2019-05-03 11:36:50 2019-05-03 11:53:30 2019-05-03 11:48:37
# 3           NaT 2019-05-03 12:32:39 2019-05-03 12:27:13 2019-05-03 12:21:01
# 4           NaT 2019-05-03 12:43:22 2019-05-03 12:58:00 2019-05-03 12:51:11
# 5           NaT 2019-05-03 13:30:47 2019-05-03 13:30:47 2019-05-03 13:34:12
# 6           NaT 2019-05-03 13:57:27 2019-05-03 13:48:52 2019-05-03 14:09:42
# 7           NaT 2019-05-03 14:18:58 2019-05-03 14:41:26 2019-05-03 14:30:50
# 8           NaT 2019-05-03 15:17:58 2019-05-03 15:17:58 2019-05-03 15:13:18
# 9           NaT 2019-05-03 16:03:08 2019-05-03 16:03:08 2019-05-03 16:00:16
# 10          NaT                 NaT 2019-05-03 16:38:11 2019-05-03 16:34:24
#
#            bulk_15_time  время_подачи_материала
# key
# 1   2019-05-03 11:10:43                  1085.0
# ...

# %%
data_bulk_time_new = data_bulk_time_new.reset_index()

# %%
data_bulk_time_new = data_bulk_time_new.drop(
    columns = [
        'bulk_3_time', 
        'bulk_4_time',
        'bulk_12_time',
        'bulk_14_time',
        'bulk_15_time'
    ], axis=1)

# %%
data_bulk_time_new.describe()
# Out:
#                key  время_подачи_материала
# count  3129.000000             3079.000000
# mean   1624.383509              872.333875
# std     933.337642              736.330538
# min       1.000000                0.000000
# 25%     816.000000              411.000000
# 50%    1622.000000              802.000000
# 75%    2431.000000             1210.000000
# max    3241.000000            13683.000000

# %% [markdown]
# В среднем время подачи материала равно 872 секундам. Есть данные с нулевым временем подачи - то есть оставшиеся материалы не добавляли в ковш

# %% [markdown]
# ### Данные о проволочных материалах (объём)

# %%
main_info(data_wire_new)
# Out:
#    key     Wire 1   Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  \
# 0    1  60.059998      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2  96.052315      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    3  91.160157      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3    4  89.063515      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4    5  89.238236  9.11456     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Wire 9
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   float64
#  2   Wire 2  1079 non-null   float64
#  3   Wire 3  63 non-null     float64
#  4   Wire 4  14 non-null     float64
#  5   Wire 5  1 non-null      float64
#  6   Wire 6  73 non-null     float64
# ...

# %% [markdown]
# Можно отметить большое количество пропущенных значений в признаках, неправильные названия столбцов.

# %%
#переименуем столбцы
data_wire_new.columns = data_wire_new.columns.str.replace(' ', '_', regex=True)
data_wire_new.columns = data_wire_new.columns.str.lower()

# %%
fig = plt.figure()

i=1
for col_name in data_wire_new.columns.tolist():
    ax = fig.add_subplot(5, 2, i)
    data_wire_new[col_name].plot(kind='hist', bins=20, figsize=(10, 15))
    ax.set_title(f'Гистограмма распределения')
    ax.set_ylabel('Частота')
    ax.set_xlabel(f'{col_name}')
    i+=1
fig.tight_layout()  
plt.show()

# %% [markdown]
# Данных многих добавок проволоки недостаточно, чтобы судить о распределении, но в признаках wire_1 и wire_2 можем наблюдать нормальное распределение объема проволоки

# %%
#посмотрим на долю пропусков в признаках
data_wire_new.isna().sum()/data_wire_new.shape[0]
# Out:
# key       0.000000
# wire_1    0.008439
# wire_2    0.649789
# wire_3    0.979552
# wire_4    0.995456
# wire_5    0.999675
# wire_6    0.976306
# wire_7    0.996430
# wire_8    0.993833
# wire_9    0.990587
# dtype: float64

# %%
#удалим все признаки с более чем 80% пропусков
data_wire_new = data_wire_new.dropna(thresh=int(len(data_wire_new) * .2), axis=1)

# %%
data_wire_new.head(10)
# Out:
#    key      wire_1     wire_2
# 0    1   60.059998        NaN
# 1    2   96.052315        NaN
# 2    3   91.160157        NaN
# 3    4   89.063515        NaN
# 4    5   89.238236   9.114560
# 5    6   99.109917   9.114560
# 6    7   98.061600        NaN
# 7    8  155.282394        NaN
# 8    9  113.393279   9.143681
# 9   10   81.244796  12.376000

# %% [markdown]
# Заменим пропуски нулями для последующего анализа

# %%
data_wire_new = data_wire_new.fillna(0)

# %% [markdown]
# ### Данные о проволочных материалах (время)

# %%
main_info(data_wire_time_new)
# Out:
#    key               Wire 1               Wire 2 Wire 3 Wire 4 Wire 5 Wire 6  \
# 0    1  2019-05-03 11:06:19                  NaN    NaN    NaN    NaN    NaN
# 1    2  2019-05-03 11:36:50                  NaN    NaN    NaN    NaN    NaN
# 2    3  2019-05-03 12:11:46                  NaN    NaN    NaN    NaN    NaN
# 3    4  2019-05-03 12:43:22                  NaN    NaN    NaN    NaN    NaN
# 4    5  2019-05-03 13:20:44  2019-05-03 13:15:34    NaN    NaN    NaN    NaN
#
#   Wire 7 Wire 8 Wire 9
# 0    NaN    NaN    NaN
# 1    NaN    NaN    NaN
# 2    NaN    NaN    NaN
# 3    NaN    NaN    NaN
# 4    NaN    NaN    NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   object
#  2   Wire 2  1079 non-null   object
#  3   Wire 3  63 non-null     object
# ...

# %% [markdown]
# Типы данных не соответствуют ожидаемому datetime, неправильные названия столбцов и большое количество пропусков

# %%
data_wire_time_new.set_index('key', inplace=True)

# %%
#переименуем столбцы
data_wire_time_new.columns = data_wire_time_new.columns.str.replace(' ', '_', regex=True)+'_time'
data_wire_time_new.columns = data_wire_time_new.columns.str.lower()

# %%
#удалим все столбцы с более 80% пропусков
data_wire_time_new = data_wire_time_new.dropna(thresh=int(len(data_wire_time_new) * .2), axis=1)

# %%
#изменим тип данных на datetime
data_wire_time_new = data_wire_time_new.apply(lambda x: pd.to_datetime(x, format='%Y-%m-%d %H:%M:%S'))

# %%
#сгенерируем новый признак по времени подачи проволоки
data_wire_time_new['время_подачи_проволоки'] = data_wire_time_new.apply(
    lambda x: (x.max()-x.min()).total_seconds(), axis=1
)

# %%
data_wire_time_new.head(10)
# Out:
#             wire_1_time         wire_2_time  время_подачи_проволоки
# key
# 1   2019-05-03 11:06:19                 NaT                     0.0
# 2   2019-05-03 11:36:50                 NaT                     0.0
# 3   2019-05-03 12:11:46                 NaT                     0.0
# 4   2019-05-03 12:43:22                 NaT                     0.0
# 5   2019-05-03 13:20:44 2019-05-03 13:15:34                   310.0
# 6   2019-05-03 13:57:27 2019-05-03 13:48:52                   515.0
# 7   2019-05-03 14:18:58                 NaT                     0.0
# 8   2019-05-03 15:01:30                 NaT                     0.0
# 9   2019-05-03 15:45:44 2019-05-03 15:39:37                   367.0
# 10  2019-05-03 16:27:00 2019-05-03 16:22:36                   264.0

# %%
data_wire_time_new = data_wire_time_new.drop(columns = ['wire_1_time', 'wire_2_time'], axis=1)

# %%
data_wire_time_new = data_wire_time_new.reset_index()

# %%
data_wire_time_new.describe()
# Out:
#                key  время_подачи_проволоки
# count  3081.000000             3070.000000
# mean   1623.426485              174.913355
# std     932.996726              290.711773
# min       1.000000                0.000000
# 25%     823.000000                0.000000
# 50%    1619.000000                0.000000
# 75%    2434.000000              361.000000
# max    3241.000000             2535.000000

# %% [markdown]
# В среднем время подачи проволоки составляет 175 секунд. Есть большое количество нулевых значений - то есть добавка проволоки не производилась

# %% [markdown]
# ### Данные о продувке сплава газом

# %%
main_info(data_gas_new)
# Out:
#    key      Газ 1
# 0    1  29.749986
# 1    2  12.555561
# 2    3  28.554793
# 3    4  18.841219
# 4    5   5.413692
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3239 non-null   int64
#  1   Газ 1   3239 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 50.7 KB
#         count         mean         std       min         25%          50%  \
# key    3239.0  1621.861377  935.386334  1.000000  812.500000  1622.000000
# Газ 1  3239.0    11.002062    6.220327  0.008399    7.043089     9.836267
#
#                75%         max
# key    2431.500000  3241.00000
# Газ 1    13.769915    77.99504

# %% [markdown]
# В датасете нет пропусков, нужно привести названия столбцов к правильному виду.

# %%
#переименуем столбцы
data_gas_new.columns = data_gas_new.columns.str.replace(' ', '_', regex=True)
data_gas_new.columns = data_gas_new.columns.str.lower()

# %%
plt.hist(data_gas_new['газ_1'], bins=30)
plt.title('Гистограмма распределения')
plt.xlabel('Газ')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# Видим, что распределение похоже на нормальное, со скошенностью вправо.

# %% [markdown]
# ###  Результаты измерения температуры

# %%
main_info(data_temp_new)
# Out:
#    key         Время замера  Температура
# 0    1  2019-05-03 11:02:04       1571.0
# 1    1  2019-05-03 11:07:18       1604.0
# 2    1  2019-05-03 11:11:34       1618.0
# 3    1  2019-05-03 11:18:04       1601.0
# 4    1  2019-05-03 11:25:59       1606.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18092 entries, 0 to 18091
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   key           18092 non-null  int64
#  1   Время замера  18092 non-null  object
#  2   Температура   14665 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 424.2+ KB
#                count         mean         std     min      25%     50%  \
# key          18092.0  1616.460977  934.641385     1.0   807.75  1618.0
# Температура  14665.0  1590.722741   20.394381  1191.0  1580.00  1590.0
#
#                 75%     max
# key          2429.0  3241.0
# Температура  1599.0  1705.0

# %% [markdown]
# Есть некоторое количество пропусков в признаке с температурой, также время замера имеет неверный тип данных.
# Минимальная температура составляет 1191 - по данным от заказчика, минимум температур = 1500

# %%
#переименуем столбцы
data_temp_new.columns = data_temp_new.columns.str.replace(' ', '_', regex=True)
data_temp_new.columns = data_temp_new.columns.str.lower()

# %%
fig = plt.figure(figsize=(10, 5))

plt.hist(data_temp_new['температура'], bins=30)
plt.title('Гистограмма распределения')
plt.ylabel('Частота')
plt.xlabel('Температура')
plt.show()

# %% [markdown]
# Гистограмма распределения температура скошена вправо

# %% [markdown]
# Выделим из данных для каждой партии температуру первого замера и температуру последнего замера

# %%
time_first = data_temp_new.groupby(by=['key'])['время_замера'].min()

# %%
temp_first = data_temp_new.merge(time_first, on='время_замера', how='inner')

# %%
temp_first = temp_first.drop('время_замера', axis=1)\
             .rename(columns = {'температура':'температура_первого_замера'})

# %%
temp_first.head(10)
# Out:
#    key  температура_первого_замера
# 0    1                      1571.0
# 1    2                      1581.0
# 2    3                      1596.0
# 3    4                      1601.0
# 4    5                      1576.0
# 5    6                      1543.0
# 6    7                      1586.0
# 7    8                      1577.0
# 8    9                      1587.0
# 9   10                      1574.0

# %%
time_last = data_temp_new.groupby(by=['key'])['время_замера'].max()

# %%
temp_last = data_temp_new.merge(time_last, on='время_замера', how='inner')

# %%
temp_last = temp_last.drop('время_замера', axis=1)\
            .rename(columns = {'температура':'температура_последнего_замера'})

# %%
temp_last.head(10)
# Out:
#    key  температура_последнего_замера
# 0    1                         1613.0
# 1    2                         1602.0
# 2    3                         1599.0
# 3    4                         1625.0
# 4    5                         1602.0
# 5    6                         1596.0
# 6    7                         1599.0
# 7    8                         1598.0
# 8    9                         1592.0
# 9   10                         1593.0

# %%
#приведем тип данных времени к datetime
data_temp_new['время_замера'] = pd.to_datetime(data_temp_new['время_замера'], format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# Агрегируем таблицу и создадим новые признаки - количество измерений и выделим время первого и последнего замеров

# %%
data_temp_pivot = data_temp_new.pivot_table(
    index='key',
    values=['температура','время_замера'],
    aggfunc={'температура':['min', 'count'],
             'время_замера':['min', 'max']
            }
)

data_temp_pivot.columns = data_temp_pivot.columns.map('_'.join)

data_temp_pivot.rename(
    columns={
        'температура_count':'количество_измерений', 
        'время_замера_min':'время_первого_замера',
        'время_замера_max':'время_последнего_замера'
    }, inplace=True)

data_temp_pivot = data_temp_pivot.reset_index()

# %%
data_temp_pivot.head(10)
# Out:
#    key время_последнего_замера время_первого_замера  количество_измерений  \
# 0    1     2019-05-03 11:30:38  2019-05-03 11:02:04                     6
# 1    2     2019-05-03 11:55:09  2019-05-03 11:34:04                     5
# 2    3     2019-05-03 12:35:57  2019-05-03 12:06:44                     6
# 3    4     2019-05-03 12:59:47  2019-05-03 12:39:27                     5
# 4    5     2019-05-03 13:36:39  2019-05-03 13:11:03                     5
# 5    6     2019-05-03 14:11:38  2019-05-03 13:46:41                     5
# 6    7     2019-05-03 14:45:40  2019-05-03 14:16:36                     5
# 7    8     2019-05-03 15:20:41  2019-05-03 14:53:46                     5
# 8    9     2019-05-03 16:06:44  2019-05-03 15:36:33                     6
# 9   10     2019-05-03 16:39:50  2019-05-03 16:13:59                     7
#
#    температура_min
# 0           1571.0
# 1           1577.0
# 2           1596.0
# 3           1601.0
# 4           1576.0
# 5           1543.0
# ...

# %% [markdown]
# Удалим ненужные данные - с количеством измерений равным 1, так как здесь нет таргета и с температурой меньше 1500

# %%
data_temp_pivot = data_temp_pivot.query('количество_измерений > 1 and температура_min >= 1500')

# %%
#сгенерируем новый признак - время между измерениями
data_temp_pivot['время_между_измерениями'] = (
    data_temp_pivot['время_последнего_замера'] - data_temp_pivot['время_первого_замера']
).dt.total_seconds()

# %%
data_temp_pivot.head(10)
# Out:
#    key время_последнего_замера время_первого_замера  количество_измерений  \
# 0    1     2019-05-03 11:30:38  2019-05-03 11:02:04                     6
# 1    2     2019-05-03 11:55:09  2019-05-03 11:34:04                     5
# 2    3     2019-05-03 12:35:57  2019-05-03 12:06:44                     6
# 3    4     2019-05-03 12:59:47  2019-05-03 12:39:27                     5
# 4    5     2019-05-03 13:36:39  2019-05-03 13:11:03                     5
# 5    6     2019-05-03 14:11:38  2019-05-03 13:46:41                     5
# 6    7     2019-05-03 14:45:40  2019-05-03 14:16:36                     5
# 7    8     2019-05-03 15:20:41  2019-05-03 14:53:46                     5
# 8    9     2019-05-03 16:06:44  2019-05-03 15:36:33                     6
# 9   10     2019-05-03 16:39:50  2019-05-03 16:13:59                     7
#
#    температура_min  время_между_измерениями
# 0           1571.0                   1714.0
# 1           1577.0                   1265.0
# ...

# %% [markdown]
# Добавим в датасет данные о первой и последней температурах

# %%
data_temp_pivot = data_temp_pivot.merge(temp_first, on='key', how='inner')

# %%
data_temp_pivot = data_temp_pivot.merge(temp_last, on='key', how='inner').drop('температура_min', axis=1)

# %%
data_temp_pivot.head()
# Out:
#    key время_последнего_замера время_первого_замера  количество_измерений  \
# 0    1     2019-05-03 11:30:38  2019-05-03 11:02:04                     6
# 1    2     2019-05-03 11:55:09  2019-05-03 11:34:04                     5
# 2    3     2019-05-03 12:35:57  2019-05-03 12:06:44                     6
# 3    4     2019-05-03 12:59:47  2019-05-03 12:39:27                     5
# 4    5     2019-05-03 13:36:39  2019-05-03 13:11:03                     5
#
#    время_между_измерениями  температура_первого_замера  \
# 0                   1714.0                      1571.0
# 1                   1265.0                      1581.0
# 2                   1753.0                      1596.0
# 3                   1220.0                      1601.0
# 4                   1536.0                      1576.0
#
#    температура_последнего_замера
# 0                         1613.0
# 1                         1602.0
# 2                         1599.0
# 3                         1625.0
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Были загружены семь датасетов, с последующим анализом и предобработкой.
# Внесены изменения в названия столбцов, типы данных изменены на верные (datetime).
#
# В первом датасете с данными об электродах не обнаружены пропуски, активная мощность имеет нормальное распределение со скошенностью вправо, присутствуют выбросы на диапазоне больших значений. На графике реактивной мощности обнаружен и удален выброс с отрицательным значением.
#
# В остальных таблицах было принято решение об удалении признаков с более чем 80% пропусков. В оставшихся случаях пропуски мы заменили на нули для последующего анализа.
#
# Для датасетов с информацией о материалах и проволоке были построены гистограммы распределения - многие не имеют нормальное распределение. wire_1 и wire_2 имеют примерно похожее на нормальное распределение. Можно обсуловить тем, что не все материалы и проволоки добавляются в ковш.
#
# В датасете с данными о продувке газом пропусков нет, распределение данных нормальное, со скошенностью вправо.
#
# В ходе агрегации датасетов были созданы новые признаки: полная мощность, число итераций нагрева и работа, а также время подачи материала и проволоки.
#
# По данным от заказчика, минимальная температура равна 1500, поэтому в датасете с данными о температуре были удалены все значения партий с температурой меньше 1500.
# Также были устранены данные с одним замером температуры, так как тут отсутствует таргет.
# Для последующего анализа были выделены первая и последняя температуры, время замера и количество измерений.

# %% [markdown]
# ## Объединение датасетов

# %%
df_list = [
    data_bulk_new,
    data_wire_new,
    data_bulk_time_new,
    data_wire_time_new,
    data_gas_new,
    data_temp_pivot
]

# %%
df_full = data_arc_pivot.copy(deep=True)

# %%
for df in df_list:
    df_full = df_full.merge(df, on='key', how='inner')

# %%
df_full.sort_values(by='key').head(10)
# Out:
#    key  активная_мощность  время_нагрева  число_итераций_нагрева  \
# 0    1           3.036730         1098.0                       5
# 1    2           2.139408          811.0                       4
# 2    3           4.063641          655.0                       5
# 3    4           2.706489          741.0                       4
# 4    5           2.252950          869.0                       4
# 5    6           2.725274          952.0                       4
# 6    7           2.626877          673.0                       4
# 7    8           2.678958          913.0                       4
# 8    9           3.520820          625.0                       5
# 9   10           3.118778          825.0                       6
#
#    реактивная_мощность  полная_мощность       работа  bulk_3  bulk_4  bulk_12  \
# 0             2.142821         3.716640  4080.870431     0.0    43.0    206.0
# 1             1.453357         2.586371  2097.546600     0.0    73.0    206.0
# ...

# %%
df_full.sort_values(by='key').tail(10)
# Out:
#        key  активная_мощность  время_нагрева  число_итераций_нагрева  \
# 2314  2489           0.930546          308.0                       2
# 2315  2490           2.668707          992.0                       5
# 2316  2492           2.325828          682.0                       3
# 2317  2493           2.199920          405.0                       3
# 2318  2494           1.504776          550.0                       3
# 2319  2495           3.168133          723.0                       4
# 2320  2496           4.174918          940.0                       6
# 2321  2497           3.605239          569.0                       3
# 2322  2498           3.202310          750.0                       5
# 2323  2499           1.737084          883.0                       4
#
#       реактивная_мощность  полная_мощность       работа  bulk_3  bulk_4  \
# 2314             0.646865         1.133292   349.053858     0.0     0.0
# ...

# %% [markdown]
# Удалим ненужные признаки для последующего анализа

# %%
df_full = df_full.drop(
    columns=['key', 'время_первого_замера', 'время_последнего_замера'], axis=1
)

# %% [markdown]
# Проверим датасет на пропуски

# %%
df_full.isna().sum()
# Out:
# активная_мощность                 0
# время_нагрева                     0
# число_итераций_нагрева            0
# реактивная_мощность               0
# полная_мощность                   0
# работа                            0
# bulk_3                            0
# bulk_4                            0
# bulk_12                           0
# bulk_14                           0
# bulk_15                           0
# wire_1                            0
# wire_2                            0
# время_подачи_материала           38
# время_подачи_проволоки            9
# газ_1                             0
# количество_измерений              0
# время_между_измерениями           0
# температура_первого_замера        0
# температура_последнего_замера     0
# dtype: int64

# %% [markdown]
# Заполним пропуски во времени подачи материала и проволоки нулями

# %%
df_full = df_full.fillna(0)

# %%
df_full.shape
# Out:
# (2324, 20)

# %% [markdown]
# ### Вывод

# %% [markdown]
# Объединили все датасеты в общий по ключу key, в датасет попали только данные тех партий, которые представлены во всех таблицах.
# Удалили признаки key, время подачи материалов и проволоки, заполнили пропуски нулями.
#
# Получили датасет с 20 признаками

# %% [markdown]
# ## Исследовательский анализ и предобработка данных объединённого датафрейма

# %% [markdown]
# Выполните исследовательский анализ объединённого датафрейма, визуализируйте распределения признаков и при необходимости выполните предобработку. Проведите корреляционный анализ.

# %%
#построение графиков для количественных признаков
for i, col_name in enumerate(df_full.select_dtypes(include='number').columns.tolist()):
    fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
    df_full[col_name].plot(kind='hist', bins=20, ax=axes[0])
    axes[0].set_title(f'Гистограмма распределения')
    #axes[0].set_xlabel(f'{labels[i]}')
    axes[0].set_ylabel('Частота')
    df_full[col_name].plot(kind='box', ax=axes[1], vert=False)
    axes[1].set_title(f'Диаграмма размаха')
    axes[1].set_xlabel(f'{col_name}')
    axes[1].set_yticks([])
    fig.tight_layout()  
    plt.show()

# %% [markdown]
# Можно отметить характерные выбросы в данных о температуре, мощности и работе.
# Диаграммы распределения сыпучих материалов и проволоки имеют неравномерное распределение по датасету.
# Данные о температуре первого и последнего замеров распределены нормально, с небольшим количеством выбросов

# %%
#построим график со значениями корреляции между всеми признаками
fig, axes = plt.subplots(figsize=(15,10))

interval_cols = df_full.columns

phik_matrix = df_full.phik_matrix(interval_cols=interval_cols)

ax = sns.heatmap(phik_matrix, annot=True, fmt='.2f')

plt.show()

# %% [markdown]
# Признаки реактивная и активная мощность имеют высокую корреляцию с признаком полная мощность, количество измерений и число итераций нагрева - мультиколлинеарны.
# Также сильную корреляцию имеют признаки: количество измерений и мощность, работа и время нагрева.

# %% [markdown]
# Посмотрим, какие признаки больше всего коррелируют с температурой последнего замера

# %%
phik_matrix.sort_values(
    by='температура_последнего_замера',ascending=False
)['температура_последнего_замера'].head(10)
# Out:
# температура_последнего_замера    1.000000
# полная_мощность                  0.487839
# активная_мощность                0.481043
# wire_1                           0.470749
# температура_первого_замера       0.425262
# время_между_измерениями          0.419587
# реактивная_мощность              0.364761
# число_итераций_нагрева           0.359897
# количество_измерений             0.359897
# bulk_15                          0.328520
# Name: температура_последнего_замера, dtype: float64

# %% [markdown]
# В равно степени корреляция таргета с полной и активной мощностями, добавкой wire_1, а также с температурой первого замера и временем между измерениями.

# %% [markdown]
# Удалим высоко коррелирующие признаки

# %%
df_full.drop(columns=['реактивная_мощность','активная_мощность', 'количество_измерений'],axis=1,inplace=True)

# %% [markdown]
# ## Подготовка данных
#
# Выполните подготовку данных для обучения модели. Разделите данные на две выборки, при масштабировании и кодировании учитывайте особенности данных и моделей.

# %%
RANDOM_STATE = 70425
TEST_SIZE = 0.25

X = df_full.drop(['температура_последнего_замера'], axis=1)
y = df_full['температура_последнего_замера']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE
)

# %%
X_train.shape
# Out:
# (1743, 16)

# %%
X_test.shape
# Out:
# (581, 16)

# %% [markdown]
# Получили не менее 1743 строки для обучающей выборки и 581 строку для тестовой выборки

# %% [markdown]
# ## Обучение моделей машинного обучения

# %% [markdown]
# Создадим пайплайн для обучения моделей, для перебора гиперпараметров используем RandomizedSearchCV

# %%
num_columns = X_train.columns

#создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %%
#создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeRegressor(random_state=RANDOM_STATE))
])

# %%
param_grid = [
    #словарь для модели DecisionTreeRegressor()
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 8),
        'models__min_samples_leaf': range(2, 8)
    },
    # словарь для модели XGBRegressor()
    {
        'models': [XGBRegressor(random_state = RANDOM_STATE)],
        'models__max_depth' : range(2, 8),
        'models__learning_rate' : [0.1, 0.2],
        'models__reg_alpha': range(1, 5),
        'models__reg_lambda': range(1, 5)
    },
    # словарь для модели CatBoostRegressor()
    {
        'models': [CatBoostRegressor(verbose = False, random_state = RANDOM_STATE)],
        'models__iterations' : [50, 100, 150],
        'models__learning_rate' : [0.1, 0.2, 0.5],
        'models__depth' : [2, 5]
    }
]

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='neg_mean_absolute_error',
    random_state=RANDOM_STATE,
    n_jobs=-1, 
    n_iter=5
)
randomized_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', MinMaxScaler(),
#                                                   Index(['время_нагрева', 'число_итераций_нагрева', 'полная_мощность', 'работа',
#        'bulk_3', 'bulk_4', 'bulk_12', 'bulk_14', 'bulk_15', 'wire_1', 'wire_2',
#        'время_подачи_материала', 'время_подачи_проволоки', 'газ_1',
#        'время_между_измерениями', 'температура_первого_замера'],
#       dtype='object'))])),
#                 ('models',
#                  <catboost.core.CatBoostRegressor object at 0x7f62ad19dd30>)])
# Метрика лучшей модели на тренировочной выборке: -6.028366532519066

# %% [markdown]
# ## Выбор лучшей модели

# %% [markdown]
# ### Сравнение моделей

# %% [markdown]
# Рассмотрим показатели моделей, показавшие лучшие результаты

# %%
result = pd.DataFrame(randomized_search.cv_results_)
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', None)
result
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.017803      0.003154         0.004213        0.000072
# 1       0.011297      0.000210         0.003789        0.000151
# 2      43.250716     49.680526         0.026053        0.022381
# 3       3.689136      0.465669         0.007914        0.000354
# 4       1.107921      0.192403         0.005013        0.000353
#
#   param_models__min_samples_leaf param_models__max_depth  \
# 0                              6                       7
# 1                              3                       3
# 2                            NaN                       7
# 3                            NaN                       6
# 4                            NaN                     NaN
#
# ...

# %% [markdown]
# Лучшей моделью является CatBoostRegressor, с показателем MAE = 6.03.
# На втором и третьем месте - XGBRegressor, c показателем MAE = 6.16 и 6.21.
# CatBoostRegressor также показывает отличную скорость обучения, по сравнению с XGBRegressor

# %% [markdown]
# Полные параметры лучшей модели:

# %%
randomized_search.best_params_
# Out:
# {'models__learning_rate': 0.1,
#  'models__iterations': 150,
#  'models__depth': 5,
#  'models': <catboost.core.CatBoostRegressor at 0x7f62b5b9fc10>}

# %% [markdown]
# ### Метрики лучшей модели

# %%
#оценим работу модели на тестовой выборке
pred = randomized_search.best_estimator_.predict(X_test)

# %%
mean_absolute_error(y_test, pred)
# Out:
# 6.045638591541714

# %%
r2_score(y_test, pred)
# Out:
# 0.44529298360614766

# %% [markdown]
# На тестовой выборке лучшая модель показала результат метрики MAE = 6.05.
# Также рассчитали метрику R2, с результатом 0.45 - достаточно неплохой результат для модели. То есть модель неплохо понимает данные и сможет показать хорошие метрики на неизвестных данных.

# %% [markdown]
# ### Сравнение с константной моделью

# %% [markdown]
# Сравним показатели с константной моделью

# %%
dummy_regressor = DummyRegressor()
dummy_regressor.fit(X_train, y_train)
dummy_pred = dummy_regressor.predict(X_test)

# %%
mean_absolute_error(y_test, dummy_pred)
# Out:
# 7.95341286463778

# %% [markdown]
# Видим, что константная модель в среднем ошибается на 7.95 значений температуры, лучшая же модель CatBoostRegressor ошибается на 6.05

# %% [markdown]
# ### Важность признаков лучшей модели

# %%
feature_importances = pd.DataFrame(
    {
        'Feature': X.columns,
        'Importance': randomized_search.best_estimator_._final_estimator.feature_importances_
    }).sort_values('Importance', ascending=False)

# %%
#построим столбчатый график
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='Importance', y='Feature', data=feature_importances)
ax.set_title('Важность признаков', fontsize=16)
ax.set_xlabel('Важность', fontsize=14)
ax.set_ylabel('Признак', fontsize=14)
plt.show()

# %% [markdown]
# Наибольшую важность для модели представляют признаки: температура первого замера, время нагрева и время между измерениями - это имеет смысл, так как это все показатели процесса нагревания, важные для показателя конечной температуры.
#
# Небольшую роль играют признаки с объемом сыпучих материалов и проволоки.
#
# Наименее важными модель расценила признаки времени подачи материалов, полную мощность и число итераций нагрева - то есть на конечную температуру влияет то, какие материалы добавляют в ковш, но не время подачи.

# %% [markdown]
# ## Общий вывод и рекомендации заказчику

# %% [markdown]
# **1  Загрузка и 2 Исследовательский анализ данных** \
# Были загружены семь датасетов, с последующим анализом и предобработкой.
# Внесены изменения в названия столбцов, типы данных изменены на верные (datetime).
#
# В первом датасете с данными об электродах не обнаружены пропуски, активная мощность имеет нормальное распределение со скошенностью вправо, присутствуют выбросы на диапазоне больших значений. На графике реактивной мощности обнаружен и удален выброс с отрицательным значением.
#
# В остальных таблицах было принято решение об удалении признаков с более чем 80% пропусков. В оставшихся случаях пропуски мы заменили на нули для последующего анализа.
#
# Для датасетов с информацией о материалах и проволоке были построены гистограммы распределения - многие не имеют нормальное распределение. wire_1 и wire_2 имеют примерно похожее на нормальное распределение. Можно обсуловить тем, что не все материалы и проволоки добавляются в ковш.
#
# В датасете с данными о продувке газом пропусков нет, распределение данных нормальное, со скошенностью вправо.
#
# В ходе агрегации датасетов были созданы новые признаки: полная мощность, число итераций нагрева и работа, а также время подачи материала и проволоки.
#
# По данным от заказчика, минимальная температура равна 1500, поэтому в датасете с данными о температуре были удалены все значения партий с температурой меньше 1500.
# Также были устранены данные с одним замером температуры, так как тут отсутствует таргет.
# Для последующего анализа были выделены первая и последняя температуры, время замера и количество измерений.
#
# **3 Объединение датасетов**\
# Объединили все датасеты в общий по ключу key, в датасет попали только данные тех партий, которые представлены во всех таблицах. Удалили признаки key, время подачи материалов и проволоки, заполнили пропуски нулями.
# Получили датасет с 20 признаками
#
# **4 Исследовательский анализ общего датасета**\
# Отметили в общем датасете характерные выбросы в данных о температуре, мощности и работе. Диаграммы распределения сыпучих материалов и проволоки имеют такое же неравномерное распределение по датасету. Данные о температуре первого и последнего замеров распределены нормально, с небольшим количеством выбросов.
#
# Далее был проведен корреляционный анализ признаков.
# Признаки реактивная и активная мощность имеют высокую корреляцию с признаком полная мощность, количество измерений и число итераций нагрева - мультиколлинеарны. Также сильную корреляцию имеют признаки: количество измерений и мощность, работа и время нагрева.
#
# В равной степени корреляция таргета с полной и активной мощностями, добавкой wire_1, а также с температурой первого замера и временем между измерениями.
#
# Было принято решение удалить признаки с реактивной и активной мощностями и количеством измерений.
#
# **5 Подготовка данных**\
# Далее разделили данные на тренировочную и тестовую выборки, получили 1743 и 581 строки соответственно.
#
# **6 Обучение моделей**\
# Использовали пайплайн для обучения моделей, для перебора гиперпараметров использовали RandomizedSearchCV
#
# **7 Выбор лучшей модели**\
# Лучшей моделью является CatBoostRegressor, с показателем MAE = 6.03. На втором и третьем месте - XGBRegressor, c показателем MAE = 6.16 и 6.21. CatBoostRegressor также показывает отличную скорость обучения, по сравнению с XGBRegressor
#
# Параметры лучшей модели:
# {'models__learning_rate': 0.1,
#  'models__iterations': 150,
#  'models__depth': 5,
#  'models': <catboost.core.CatBoostRegressor at 0x7fb36714c640>}
#  random_state=70425
#
# На тестовой выборке лучшая модель показала результат метрики MAE = 6.05. Также рассчитали метрику R2, с результатом 0.45 - достаточно неплохой результат для модели. То есть модель неплохо понимает данные и сможет показать хорошие метрики на неизвестных данных.
#
# Сравнили константную модель с лучшей - константная модель в среднем ошибается на 7.95 значений температуры, лучшая же модель CatBoostRegressor ошибается на 6.05.
#
# Далее произвели анализ важности признаков. Наибольшую важность для модели представляют признаки: температура первого замера, время нагрева и время между измерениями - это имеет смысл, так как это все показатели процесса нагревания, важные для показателя конечной температуры.
# Небольшую роль играют признаки с объемом сыпучих материалов и проволоки.
# Наименее важными модель расценила признаки времени подачи материалов, полную мощность и число итераций нагрева - то есть на конечную температуру влияет то, какие материалы добавляют в ковш, но не время подачи.
#
# Для улучшения качества предсказаний модели можно порекомендовать применить отбор признаков, например, с помощью метода перестановки permutation importance - чтобы вычислить, какие признаки на самом деле важны для модели, а какие она использует для подстройки и переобучения.
#
# Также можно сгенерировать большее количество признаков, попробовать подбор большего количества гиперпараметров.
